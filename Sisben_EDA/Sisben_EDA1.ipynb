# %%
import pandas as pd
# Instalar pyreadstat en el terminal previamente, ya sea con pip install pyreadstat
import pyreadstat as pyreadstat

# %%
chunk = pd.read_csv('../data/1-bronce/SISBEN_DIC_2020_FILT.csv', chunksize = 100000)
df = pd.concat(chunk)
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (83) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (31,32,33,34,83) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Unnamed: 0  id_registro  depto  munic    ficha  zona  sector  seccion  \
# 0           1   60020604.0     11      1  4960798     1    4566       66
# 1           2   60020660.0     11      1  4960836     1    4603        3
# 2           3   60020663.0     11      1  3096561     1    1414       14
# 3           4   60020676.0     11      1  5106178     1    5621       21
# 4           5   60020684.0     11      1  4960790     1    4511       11
#
#    manzana  comuna  barrio               nombarrio  \
# 0     25.0       8    4566        PATIO BONITO III
# 1     28.0       8    4603              EL PARAISO
# 2     58.0      18    1414         MOLINOS DEL SUR
# 3     64.0      10    5621          FLORIDA BLANCA
# 4     55.0       8    4511  CIUDAD KENNEDY CENTRAL
#
#                               direcc  vereda           nomvereda      teles  \
# 0       KR 88 BIS 0 31 SUR PI 1 CU 1       0  BARRIO ZONA URBANA        0.0
# ...

# %%
df["edad"].describe()
# Out:
# count    873843.000000
# mean          7.082731
# std           6.498742
# min           0.000000
# 25%           2.000000
# 50%           6.000000
# 75%          10.000000
# max         100.000000
# Name: edad, dtype: float64

# %%
df["depto"].unique()
# Out:
# array([11])

# %%
df["munic"].unique()
# Out:
# array([1])

# %%
pd.set_option('display.max_rows', None) 
df.isna().sum()
# Out:
# Unnamed: 0               0
# id_registro              0
# depto                    0
# munic                    0
# ficha                    0
# zona                     0
# sector                   0
# seccion                  0
# manzana              16225
# comuna                   0
# barrio                   0
# nombarrio                0
# direcc                   0
# vereda                   0
# nomvereda                0
# teles                    1
# vivienda                 0
# pared                    0
# piso                     0
# energia                  0
# alcanta                  0
# gas                      0
# telefono                 0
# basura                   0
# acueduc                  0
# estrato                  0
# elimbasura               0
# tcuartosvi               0
# thogar                   0
# recolec                  0
# entidad                  0
# encuesta                 0
# supervi                  0
# digita                   0
# ...
