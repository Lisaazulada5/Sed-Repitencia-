# %%
# Scientific libraries
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt


# model libraries 
from scipy.stats import chi2_contingency, norm
from scipy.stats import chi2_contingency, ttest_ind
import researchpy as rp
import scipy.stats as stats

import statsmodels.api as sm
import statsmodels.formula.api as smf


from sklearn.metrics import roc_curve, auc


plt.rc("figure", figsize=(16,8))
plt.rc("font", size=14)
# Pandas options
pd.options.display.max_columns = None

# %%
dict_tipos = {
# parte simat
'ANO_INF':              'uint16',
'CODIGO_DANE':          'uint64',
'CODIGO_DANE_SEDE':     'uint64',
'TIPO_DOCUMENTO':       'uint8',
'NRO_DOCUMENTO':        'string',
'DIRECCION_RESIDENCIA': 'string',
'RES_DEPTO':            'uint8',
'RES_MUN':              'uint16',
'ESTRATO':              'uint8',
'SISBEN':               'float16',
'GENERO':               'uint8',
'POB_VICT_CONF':        'uint8',
'PROVIENE_SECTOR_PRIV': 'string',
'PROVIENE_OTR_MUN':     'string',
'TIPO_DISCAPACIDAD':    'uint8',
'CAP_EXC':              'uint8',
'CODIGO_ETNIA':         'uint16',
'CODIGO_JORNADA':       'uint8',
'CARACTER':             'uint8',
'CODIGO_ESPECIALIDAD':  'uint8',
'CODIGO_GRADO':         'int8',
'CODIGO_METODOLOGIA':   'uint8',
'REPITENTE':            'uint8',
'SIT_ACAD_ANIO_ANT':    'uint8',
'CON_ALUM_ANIO_ANT':    'uint8',
'ZONA_RESI_ALU':        'uint8',
'EDAD':                 'uint8',
'NIVEL':                'uint8',
'DIR_NUM_LOCALIDAD':    'uint8',
'NIVEL_SISBEN':         'uint8',
'GRADO_OVERAGE':        'uint8',
'OVERAGE':        'uint8',
# parte sisben
'ficha': 'int64',
'comuna': 'uint8',
'barrio': 'uint32',
'nombarrio': 'string',
'direcc':'string',
'vereda': 'uint8',
'nomvereda':'string',
'vivienda': 'uint8',
'pared': 'uint8',
'piso': 'uint8',
'energia':'uint8',
'alcanta':'uint8',
'gas': 'uint8',
'telefono' : 'uint8',
'basura' : 'uint8',
'acueduc' : 'uint8',
'estrato' : 'uint8',
'elimbasura' : 'uint8',
'tcuartosvi' : 'uint8',
'thogar' : 'uint8',
'recolec' : 'uint8',
'tipdir' : 'uint8',
'verifica' : 'uint8',
'hogar' : 'uint8',
'teneviv' : 'uint8',
'tcuartos' : 'uint8',
'tdormir' : 'uint8',
'sanitar' : 'uint8',
'usanitar' : 'uint8',
'usosani' : 'uint8',
'tsanitar' : 'uint8',
'ducha' : 'uint8',
'agua' : 'uint8',
'llega' : 'uint8',
'cuandi' : 'uint8',
'suminis' : 'uint8',
'cuanhoras' : 'uint8',
'preparan' : 'uint8',
'cocina' : 'uint8',
'cocinan' : 'uint8',
'alumbra' : 'uint8',
'usotele' : 'uint8',
'nevera' : 'uint8',
'lavadora' : 'uint8',
'tvcolor' : 'uint8',
'tvcable' : 'uint8',
'calenta' : 'uint8',
'horno' : 'uint8',
'aire' : 'uint8',
'computador' : 'uint8',
'equipo' : 'uint8',
'moto' : 'uint8',
'tractor' : 'uint8',
'tiene_auto' : 'uint8',
'bieraices': 'uint8',
'tpersona' : 'uint8',
'informan' : 'uint8',
'orden' : 'uint8',
'nucleo' : 'uint8',
'parentes' : 'uint8',
'tipodoc' : 'uint8',
'documen':'string',
'sexo' : 'uint8',
'estcivil' : 'uint8',
'discapa' : 'uint8',
'carnet' : 'uint8',
'asiste' : 'uint8',
'tipoesta' : 'uint8',
'grado' : 'uint8',
'nivel' : 'uint8',
'activi' : 'uint8',
'buscando' : 'uint8',
'ingresos': 'int64',
'edad':'uint8',
'conyuvive': 'uint8',
'hijosde':'int8',
'embaraza' : 'uint8',
'extranjero' : 'uint8',
'pagapor' : 'uint8',
'percibe' : 'uint8',
'serdomes' : 'uint8',
'unigasto' : 'uint8',
'area' : 'uint8',
'nparentes':'uint8',
'puntaje_sisben_3':'float32',
'todos_servicios_Pub':'uint8',
'indice_hacinamiento': 'float16',
# parte c-600  
# parte ICFES
  }

# %%
df = pd.read_csv('../data/3-oro/Merge_2020_ICFES_C600.csv' , index_col=0, dtype = dict_tipos)

# %%
df.head(1)
# Out:
#    ANO_INF   CODIGO_DANE  CODIGO_DANE_SEDE  TIPO_DOCUMENTO NRO_DOCUMENTO  \
# 0     2020  111001000078      111001000078               2    1000004716
#
#          DIRECCION_RESIDENCIA  RES_DEPTO  RES_MUN  ESTRATO  SISBEN  \
# 0  CL 29 A SUR # 50 - 41 PL 2         11        1        3    29.0
#
#   FECHA_NACIMIENTO  GENERO  POB_VICT_CONF PROVIENE_SECTOR_PRIV  \
# 0       2003-04-14       0             99                    0
#
#   PROVIENE_OTR_MUN  TIPO_DISCAPACIDAD  CAP_EXC  CODIGO_ETNIA  CODIGO_JORNADA  \
# 0                0                  0        9             0               6
#
#    CARACTER  CODIGO_ESPECIALIDAD  CODIGO_GRADO  CODIGO_METODOLOGIA  REPITENTE  \
# 0         1                    5            10                   1          0
#
#    SIT_ACAD_ANIO_ANT  CON_ALUM_ANIO_ANT  ZONA_RESI_ALU  EDAD  NIVEL  \
# 0                  1                  9              1    16      4
#
#    DIR_NUM_LOCALIDAD  NIVEL_SISBEN  GRADO_OVERAGE  OVERAGE    ficha  comuna  \
# 0                 16             1            100        0  4304159      16
#
#    barrio nombarrio                            direcc  vereda  \
# 0    4407    ALCALA  CL  33 SUR  51 A  47 PI  1 CU  1       0
#
#             nomvereda  vivienda  pared  piso  energia  alcanta  gas  telefono  \
# 0  BARRIO ZONA URBANA         2      1     2        1        1    1         2
#
#    basura  acueduc  estrato  elimbasura  tcuartosvi  thogar  recolec  tipdir  \
# 0       1        1        3           1           2       1        3       1
#
#    verifica  hogar  teneviv  tcuartos  tdormir  sanitar  usanitar  usosani  \
# 0         1      1        1         2        2        1         1        2
#
#    tsanitar  ducha  agua  llega  cuandi  suminis  cuanhoras  preparan  cocina  \
# 0         1      1     1      1       0        1          0         1       2
#
#    cocinan  alumbra  usotele  nevera  lavadora  tvcolor  tvcable  calenta  \
# 0        2        1        0       1         1        1        2        2
#
#    horno  aire  computador  equipo  moto  tractor  tiene_auto  bieraices  \
# 0      2     2           0       2     0        0           0          1
#
#    tpersona  informan  orden  nucleo  parentes  tipodoc  sexo  estcivil  \
# 0         5         2      4       1         3        2     0         5
#
#    discapa  carnet  asiste  tipoesta  grado  nivel  activi  buscando  \
# 0        0       0       1         4      3      1       3         0
#
#    ingresos  edad  conyuvive  hijosde  embaraza  extranjero  pagapor  percibe  \
# 0         0     8          0        0         0           0        0        0
#
#    serdomes  unigasto  area  nparentes  puntaje_sisben_3  nivel_hacinamiento  \
# 0         0         1     1          3         29.440001  Hacinamiento_medio
#
#    todos_servicios_Pub  indice_hacinamiento  ES_BILINGUE  TOTAL_DOCENTES  \
# 0                    1                  2.5            0              27
#
#    TOTAL_ALUMNOS  TOTAL_EQUIPO_COMPUTO  ALUMN_POR_DOCENTE  COMPU_POR_ALUMN  \
# 0            627                   231          23.222222         0.368421
#
#    TOTAL_DOCENTES_CON_TITULO  PROP_DOCENTES_CON_TITULO  promepuntaje  \
# 0                         24                  0.888889    262.909091
#
#    num_presentaron_ICFES
# 0                     33

# %% [markdown]
# ## Variables de consideracion inicial

# %%
variables = ['estrato',
             'EDAD',
             'puntaje_sisben_3',
             'PROP_DOCENTES_CON_TITULO',
             'promepuntaje',
             'COMPU_POR_ALUMN', 
             "ALUMN_POR_DOCENTE"
            ]


categorias= ['GENERO',  
             'DIR_NUM_LOCALIDAD',
             'todos_servicios_Pub',
             'computador',
             'OVERAGE',
             'ES_BILINGUE',
             "nivel_hacinamiento",
             "TIPO_DISCAPACIDAD",
             "tiene_auto"
             ]

# %%
def formula_maker(dependiente, variables, categorias):
    formula = f'{dependiente} ~ '
    for variable in variables:
        if formula != f'{dependiente} ~ ':
            formula += ' + '
        formula += f'{variable}'
    for categoria in categorias:
        if formula != f'{dependiente} ~ ':
            formula += ' + '
        formula += f'C({categoria})'
    return formula

# %%
formula_maker('REPITENTE', variables, categorias)
# Out:
# 'REPITENTE ~ estrato + EDAD + puntaje_sisben_3 + PROP_DOCENTES_CON_TITULO + promepuntaje + COMPU_POR_ALUMN + ALUMN_POR_DOCENTE + C(GENERO) + C(DIR_NUM_LOCALIDAD) + C(todos_servicios_Pub) + C(computador) + C(OVERAGE) + C(ES_BILINGUE) + C(nivel_hacinamiento) + C(TIPO_DISCAPACIDAD) + C(tiene_auto)'

# %% [markdown]
# **OJO en la formula se puso  C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento")) para cambiar el nivel de referencia**

# %% [markdown]
# PS: si se puede meter variables en texto como categorías en los modelos. Esto vuelve más legible la tabla de salida

# %%
formula = 'REPITENTE ~ estrato + EDAD + puntaje_sisben_3 + PROP_DOCENTES_CON_TITULO + promepuntaje + COMPU_POR_ALUMN + ALUMN_POR_DOCENTE + C(GENERO) + C(DIR_NUM_LOCALIDAD) + C(todos_servicios_Pub) + C(computador) + C(OVERAGE) + C(ES_BILINGUE) + C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento")) + C(TIPO_DISCAPACIDAD) + C(tiene_auto)'

# %% [markdown]
# # MODELOS

# %% [markdown]
# ## Modelo en primaria

# %%
df_prim = df[(df["NIVEL"] == 2) & (df["CODIGO_METODOLOGIA"] == 1)]

# %%
# sin b|alancear 
model= smf.logit(formula= formula, data= df_prim).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.138359
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              REPITENTE   No. Observations:               179094
# Model:                          Logit   Df Residuals:                   179058
# Method:                           MLE   Df Model:                           35
# Date:                Fri, 01 Jul 2022   Pseudo R-squ.:                 0.08722
# Time:                        03:42:34   Log-Likelihood:                -24779.
# converged:                       True   LL-Null:                       -27147.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==========================================================================================================================================================
#                                                                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                 -5.7564      0.316    -18.223      0.000      -6.376      -5.137
# C(GENERO)[T.1]                                                                             0.2973      0.027     10.956      0.000       0.244       0.350
# C(DIR_NUM_LOCALIDAD)[T.2]                                                                  0.6205      0.238      2.602      0.009       0.153       1.088
# C(DIR_NUM_LOCALIDAD)[T.3]                                                                  0.4052      0.153      2.649      0.008       0.105       0.705
# C(DIR_NUM_LOCALIDAD)[T.4]                                                                  0.6046      0.102      5.934      0.000       0.405       0.804
# C(DIR_NUM_LOCALIDAD)[T.5]                                                                  0.6295      0.099      6.341      0.000       0.435       0.824
# C(DIR_NUM_LOCALIDAD)[T.6]                                                                  0.5319      0.109      4.861      0.000       0.317       0.746
# C(DIR_NUM_LOCALIDAD)[T.7]                                                                  0.6906      0.097      7.133      0.000       0.501       0.880
# C(DIR_NUM_LOCALIDAD)[T.8]                                                                  0.0145      0.100      0.145      0.885      -0.181       0.210
# C(DIR_NUM_LOCALIDAD)[T.9]                                                                  0.6512      0.119      5.458      0.000       0.417       0.885
# C(DIR_NUM_LOCALIDAD)[T.10]                                                                 0.3730      0.105      3.557      0.000       0.167       0.579
# C(DIR_NUM_LOCALIDAD)[T.11]                                                                 0.4519      0.101      4.474      0.000       0.254       0.650
# C(DIR_NUM_LOCALIDAD)[T.12]                                                                -0.3474      0.183     -1.900      0.057      -0.706       0.011
# C(DIR_NUM_LOCALIDAD)[T.13]                                                                -1.1925      0.513     -2.323      0.020      -2.199      -0.186
# C(DIR_NUM_LOCALIDAD)[T.14]                                                                 0.5811      0.149      3.901      0.000       0.289       0.873
# C(DIR_NUM_LOCALIDAD)[T.15]                                                                 0.1085      0.173      0.627      0.531      -0.231       0.448
# C(DIR_NUM_LOCALIDAD)[T.16]                                                                 0.0889      0.138      0.642      0.521      -0.182       0.360
# C(DIR_NUM_LOCALIDAD)[T.17]                                                                 0.7789      0.229      3.397      0.001       0.330       1.228
# C(DIR_NUM_LOCALIDAD)[T.18]                                                                 0.3016      0.104      2.903      0.004       0.098       0.505
# C(DIR_NUM_LOCALIDAD)[T.19]                                                                 0.6647      0.098      6.768      0.000       0.472       0.857
# C(DIR_NUM_LOCALIDAD)[T.20]                                                                 0.6721      0.455      1.477      0.140      -0.220       1.564
# C(todos_servicios_Pub)[T.1]                                                               -0.1260      0.036     -3.510      0.000      -0.196      -0.056
# C(computador)[T.1]                                                                        -0.1600      0.046     -3.479      0.001      -0.250      -0.070
# C(OVERAGE)[T.1]                                                                            1.7864      0.038     47.587      0.000       1.713       1.860
# C(ES_BILINGUE)[T.1]                                                                       -0.2604      0.088     -2.972      0.003      -0.432      -0.089
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_crítico]     0.2743      0.044      6.229      0.000       0.188       0.361
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_medio]       0.1406      0.032      4.393      0.000       0.078       0.203
# C(TIPO_DISCAPACIDAD)[T.1]                                                                 -0.4753      0.060     -7.934      0.000      -0.593      -0.358
# C(tiene_auto)[T.1]                                                                        -0.3671      0.150     -2.454      0.014      -0.660      -0.074
# estrato                                                                                   -0.0810      0.025     -3.259      0.001      -0.130      -0.032
# EDAD                                                                                       0.0754      0.008      9.180      0.000       0.059       0.092
# puntaje_sisben_3                                                                          -0.0040      0.001     -4.243      0.000      -0.006      -0.002
# PROP_DOCENTES_CON_TITULO                                                                   0.5166      0.053      9.837      0.000       0.414       0.620
# promepuntaje                                                                               0.0027      0.001      2.504      0.012       0.001       0.005
# COMPU_POR_ALUMN                                                                            0.4886      0.136      3.581      0.000       0.221       0.756
# ALUMN_POR_DOCENTE                                                                          0.0029      0.004      0.780      0.435      -0.004       0.010
# ==========================================================================================================================================================
# """

# %%
# balanceado 
df_prim_rep = df_prim[df_prim['REPITENTE'] == 1]
df_prim_no_rep = df_prim[df_prim['REPITENTE'] == 0].sample(n=df_prim_rep.shape[0], random_state=145)
df_prim_balanc = pd.concat([df_prim_rep, df_prim_no_rep])

# %%
model= smf.logit(formula= formula, data= df_prim_balanc).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.610869
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              REPITENTE   No. Observations:                12522
# Model:                          Logit   Df Residuals:                    12486
# Method:                           MLE   Df Model:                           35
# Date:                Fri, 01 Jul 2022   Pseudo R-squ.:                  0.1187
# Time:                        03:43:06   Log-Likelihood:                -7649.3
# converged:                       True   LL-Null:                       -8679.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==========================================================================================================================================================
#                                                                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                 -2.2705      0.488     -4.657      0.000      -3.226      -1.315
# C(GENERO)[T.1]                                                                             0.3018      0.039      7.673      0.000       0.225       0.379
# C(DIR_NUM_LOCALIDAD)[T.2]                                                                  0.3353      0.336      0.999      0.318      -0.322       0.993
# C(DIR_NUM_LOCALIDAD)[T.3]                                                                  0.4635      0.220      2.109      0.035       0.033       0.894
# C(DIR_NUM_LOCALIDAD)[T.4]                                                                  0.6307      0.140      4.494      0.000       0.356       0.906
# C(DIR_NUM_LOCALIDAD)[T.5]                                                                  0.5474      0.136      4.036      0.000       0.282       0.813
# C(DIR_NUM_LOCALIDAD)[T.6]                                                                  0.5110      0.151      3.376      0.001       0.214       0.808
# C(DIR_NUM_LOCALIDAD)[T.7]                                                                  0.6135      0.131      4.671      0.000       0.356       0.871
# C(DIR_NUM_LOCALIDAD)[T.8]                                                                  0.0905      0.134      0.673      0.501      -0.173       0.354
# C(DIR_NUM_LOCALIDAD)[T.9]                                                                  0.7197      0.170      4.234      0.000       0.387       1.053
# C(DIR_NUM_LOCALIDAD)[T.10]                                                                 0.5065      0.144      3.527      0.000       0.225       0.788
# C(DIR_NUM_LOCALIDAD)[T.11]                                                                 0.4395      0.137      3.216      0.001       0.172       0.707
# C(DIR_NUM_LOCALIDAD)[T.12]                                                                -0.5231      0.237     -2.203      0.028      -0.988      -0.058
# C(DIR_NUM_LOCALIDAD)[T.13]                                                                -0.8151      0.652     -1.250      0.211      -2.093       0.463
# C(DIR_NUM_LOCALIDAD)[T.14]                                                                 0.7491      0.218      3.431      0.001       0.321       1.177
# C(DIR_NUM_LOCALIDAD)[T.15]                                                                 0.0323      0.235      0.138      0.890      -0.428       0.492
# C(DIR_NUM_LOCALIDAD)[T.16]                                                                 0.0898      0.187      0.481      0.630      -0.276       0.456
# C(DIR_NUM_LOCALIDAD)[T.17]                                                                 0.3890      0.346      1.124      0.261      -0.289       1.067
# C(DIR_NUM_LOCALIDAD)[T.18]                                                                 0.3134      0.140      2.242      0.025       0.039       0.587
# C(DIR_NUM_LOCALIDAD)[T.19]                                                                 0.6754      0.135      5.016      0.000       0.411       0.939
# C(DIR_NUM_LOCALIDAD)[T.20]                                                                 1.6213      1.129      1.436      0.151      -0.591       3.833
# C(todos_servicios_Pub)[T.1]                                                               -0.1058      0.055     -1.925      0.054      -0.214       0.002
# C(computador)[T.1]                                                                        -0.1249      0.064     -1.949      0.051      -0.250       0.001
# C(OVERAGE)[T.1]                                                                            1.6203      0.065     24.751      0.000       1.492       1.749
# C(ES_BILINGUE)[T.1]                                                                       -0.2701      0.125     -2.165      0.030      -0.515      -0.026
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_crítico]     0.4206      0.067      6.319      0.000       0.290       0.551
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_medio]       0.1888      0.046      4.113      0.000       0.099       0.279
# C(TIPO_DISCAPACIDAD)[T.1]                                                                 -0.0623      0.101     -0.619      0.536      -0.260       0.135
# C(tiene_auto)[T.1]                                                                        -0.5687      0.192     -2.970      0.003      -0.944      -0.193
# estrato                                                                                   -0.0858      0.037     -2.326      0.020      -0.158      -0.014
# EDAD                                                                                       0.1313      0.013     10.227      0.000       0.106       0.156
# puntaje_sisben_3                                                                          -0.0059      0.001     -4.260      0.000      -0.009      -0.003
# PROP_DOCENTES_CON_TITULO                                                                   0.4585      0.076      5.995      0.000       0.309       0.608
# promepuntaje                                                                               0.0003      0.002      0.196      0.844      -0.003       0.004
# COMPU_POR_ALUMN                                                                            0.6254      0.206      3.033      0.002       0.221       1.029
# ALUMN_POR_DOCENTE                                                                          0.0016      0.006      0.281      0.779      -0.009       0.012
# ==========================================================================================================================================================
# """

# %% [markdown]
# ## Modelo en secundaria

# %%
df_secund = df[(df["NIVEL"] == 3) & (df["CODIGO_METODOLOGIA"] == 1)]

# %%
# sin b|alancear 
model= smf.logit(formula= formula, data= df_secund).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.204740
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              REPITENTE   No. Observations:               182074
# Model:                          Logit   Df Residuals:                   182038
# Method:                           MLE   Df Model:                           35
# Date:                Fri, 01 Jul 2022   Pseudo R-squ.:                 0.09958
# Time:                        03:43:29   Log-Likelihood:                -37278.
# converged:                       True   LL-Null:                       -41401.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==========================================================================================================================================================
#                                                                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                 -4.7988      0.261    -18.402      0.000      -5.310      -4.288
# C(GENERO)[T.1]                                                                             0.2141      0.021     10.312      0.000       0.173       0.255
# C(DIR_NUM_LOCALIDAD)[T.2]                                                                  0.0006      0.158      0.004      0.997      -0.308       0.310
# C(DIR_NUM_LOCALIDAD)[T.3]                                                                 -0.9076      0.128     -7.115      0.000      -1.158      -0.658
# C(DIR_NUM_LOCALIDAD)[T.4]                                                                 -0.4728      0.066     -7.205      0.000      -0.601      -0.344
# C(DIR_NUM_LOCALIDAD)[T.5]                                                                 -0.1493      0.061     -2.435      0.015      -0.269      -0.029
# C(DIR_NUM_LOCALIDAD)[T.6]                                                                 -0.1254      0.067     -1.869      0.062      -0.257       0.006
# C(DIR_NUM_LOCALIDAD)[T.7]                                                                 -0.2742      0.060     -4.557      0.000      -0.392      -0.156
# C(DIR_NUM_LOCALIDAD)[T.8]                                                                 -0.9943      0.063    -15.706      0.000      -1.118      -0.870
# C(DIR_NUM_LOCALIDAD)[T.9]                                                                 -0.0982      0.077     -1.276      0.202      -0.249       0.053
# C(DIR_NUM_LOCALIDAD)[T.10]                                                                -0.6063      0.066     -9.164      0.000      -0.736      -0.477
# C(DIR_NUM_LOCALIDAD)[T.11]                                                                -0.2727      0.063     -4.359      0.000      -0.395      -0.150
# C(DIR_NUM_LOCALIDAD)[T.12]                                                                -0.7873      0.106     -7.434      0.000      -0.995      -0.580
# C(DIR_NUM_LOCALIDAD)[T.13]                                                                -0.0121      0.149     -0.082      0.935      -0.304       0.279
# C(DIR_NUM_LOCALIDAD)[T.14]                                                                -0.0639      0.103     -0.622      0.534      -0.265       0.137
# C(DIR_NUM_LOCALIDAD)[T.15]                                                                -0.5042      0.109     -4.624      0.000      -0.718      -0.290
# C(DIR_NUM_LOCALIDAD)[T.16]                                                                -0.9717      0.097     -9.969      0.000      -1.163      -0.781
# C(DIR_NUM_LOCALIDAD)[T.17]                                                                 0.0994      0.143      0.695      0.487      -0.181       0.380
# C(DIR_NUM_LOCALIDAD)[T.18]                                                                -0.4840      0.065     -7.407      0.000      -0.612      -0.356
# C(DIR_NUM_LOCALIDAD)[T.19]                                                                -0.2346      0.061     -3.828      0.000      -0.355      -0.115
# C(DIR_NUM_LOCALIDAD)[T.20]                                                                 0.0510      0.288      0.177      0.859      -0.514       0.616
# C(todos_servicios_Pub)[T.1]                                                               -0.0035      0.029     -0.119      0.905      -0.061       0.054
# C(computador)[T.1]                                                                        -0.1193      0.031     -3.893      0.000      -0.179      -0.059
# C(OVERAGE)[T.1]                                                                            1.4770      0.027     55.653      0.000       1.425       1.529
# C(ES_BILINGUE)[T.1]                                                                       -0.1382      0.063     -2.177      0.029      -0.263      -0.014
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_crítico]     0.0933      0.036      2.598      0.009       0.023       0.164
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_medio]       0.0607      0.023      2.589      0.010       0.015       0.107
# C(TIPO_DISCAPACIDAD)[T.1]                                                                 -0.8309      0.060    -13.742      0.000      -0.949      -0.712
# C(tiene_auto)[T.1]                                                                         0.0366      0.075      0.486      0.627      -0.111       0.184
# estrato                                                                                    0.0237      0.019      1.246      0.213      -0.014       0.061
# EDAD                                                                                       0.1274      0.008     16.057      0.000       0.112       0.143
# puntaje_sisben_3                                                                          -0.0012      0.001     -1.651      0.099      -0.003       0.000
# PROP_DOCENTES_CON_TITULO                                                                   0.4434      0.041     10.817      0.000       0.363       0.524
# promepuntaje                                                                               0.0016      0.001      1.902      0.057   -5.03e-05       0.003
# COMPU_POR_ALUMN                                                                            0.2078      0.097      2.134      0.033       0.017       0.399
# ALUMN_POR_DOCENTE                                                                         -0.0234      0.003     -8.156      0.000      -0.029      -0.018
# ==========================================================================================================================================================
# """

# %%
# balanceado 
df_secund_rep = df_secund[df_secund['REPITENTE'] == 1]
df_secund_no_rep = df_secund[df_secund['REPITENTE'] == 0].sample(n=df_secund_rep.shape[0], random_state=145)
df_secund_balanc = pd.concat([df_secund_rep, df_secund_no_rep])

# %%
model= smf.logit(formula= formula, data= df_secund_balanc).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595817
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              REPITENTE   No. Observations:                21904
# Model:                          Logit   Df Residuals:                    21868
# Method:                           MLE   Df Model:                           35
# Date:                Fri, 01 Jul 2022   Pseudo R-squ.:                  0.1404
# Time:                        03:43:58   Log-Likelihood:                -13051.
# converged:                       True   LL-Null:                       -15183.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==========================================================================================================================================================
#                                                                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                 -2.4350      0.393     -6.201      0.000      -3.205      -1.665
# C(GENERO)[T.1]                                                                             0.2710      0.030      9.003      0.000       0.212       0.330
# C(DIR_NUM_LOCALIDAD)[T.2]                                                                 -0.1884      0.253     -0.745      0.456      -0.684       0.307
# C(DIR_NUM_LOCALIDAD)[T.3]                                                                 -0.9357      0.184     -5.078      0.000      -1.297      -0.575
# C(DIR_NUM_LOCALIDAD)[T.4]                                                                 -0.5043      0.100     -5.023      0.000      -0.701      -0.308
# C(DIR_NUM_LOCALIDAD)[T.5]                                                                 -0.1792      0.095     -1.880      0.060      -0.366       0.008
# C(DIR_NUM_LOCALIDAD)[T.6]                                                                 -0.2160      0.104     -2.069      0.039      -0.421      -0.011
# C(DIR_NUM_LOCALIDAD)[T.7]                                                                 -0.3086      0.093     -3.321      0.001      -0.491      -0.126
# C(DIR_NUM_LOCALIDAD)[T.8]                                                                 -0.9702      0.095    -10.186      0.000      -1.157      -0.783
# C(DIR_NUM_LOCALIDAD)[T.9]                                                                 -0.0156      0.124     -0.125      0.900      -0.259       0.228
# C(DIR_NUM_LOCALIDAD)[T.10]                                                                -0.5554      0.102     -5.449      0.000      -0.755      -0.356
# C(DIR_NUM_LOCALIDAD)[T.11]                                                                -0.3493      0.096     -3.620      0.000      -0.538      -0.160
# C(DIR_NUM_LOCALIDAD)[T.12]                                                                -0.8780      0.157     -5.585      0.000      -1.186      -0.570
# C(DIR_NUM_LOCALIDAD)[T.13]                                                                -0.2966      0.235     -1.263      0.206      -0.757       0.164
# C(DIR_NUM_LOCALIDAD)[T.14]                                                                -0.3206      0.158     -2.025      0.043      -0.631      -0.010
# C(DIR_NUM_LOCALIDAD)[T.15]                                                                -0.6551      0.161     -4.080      0.000      -0.970      -0.340
# C(DIR_NUM_LOCALIDAD)[T.16]                                                                -1.0392      0.141     -7.355      0.000      -1.316      -0.762
# C(DIR_NUM_LOCALIDAD)[T.17]                                                                -0.0239      0.241     -0.099      0.921      -0.495       0.448
# C(DIR_NUM_LOCALIDAD)[T.18]                                                                -0.4563      0.099     -4.590      0.000      -0.651      -0.261
# C(DIR_NUM_LOCALIDAD)[T.19]                                                                -0.3036      0.095     -3.206      0.001      -0.489      -0.118
# C(DIR_NUM_LOCALIDAD)[T.20]                                                                -0.2355      0.497     -0.474      0.636      -1.210       0.739
# C(todos_servicios_Pub)[T.1]                                                               -0.0789      0.044     -1.783      0.075      -0.166       0.008
# C(computador)[T.1]                                                                        -0.1588      0.044     -3.639      0.000      -0.244      -0.073
# C(OVERAGE)[T.1]                                                                            1.3868      0.039     35.137      0.000       1.309       1.464
# C(ES_BILINGUE)[T.1]                                                                       -0.1690      0.094     -1.791      0.073      -0.354       0.016
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_crítico]     0.0492      0.054      0.918      0.359      -0.056       0.154
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_medio]       0.0714      0.034      2.076      0.038       0.004       0.139
# C(TIPO_DISCAPACIDAD)[T.1]                                                                 -0.8116      0.091     -8.943      0.000      -0.989      -0.634
# C(tiene_auto)[T.1]                                                                         0.2124      0.111      1.922      0.055      -0.004       0.429
# estrato                                                                                    0.0316      0.028      1.114      0.265      -0.024       0.087
# EDAD                                                                                       0.2243      0.012     18.419      0.000       0.200       0.248
# puntaje_sisben_3                                                                          -0.0016      0.001     -1.506      0.132      -0.004       0.000
# PROP_DOCENTES_CON_TITULO                                                                   0.4099      0.059      6.975      0.000       0.295       0.525
# promepuntaje                                                                              -0.0010      0.001     -0.780      0.436      -0.004       0.002
# COMPU_POR_ALUMN                                                                            0.2364      0.150      1.571      0.116      -0.058       0.531
# ALUMN_POR_DOCENTE                                                                         -0.0281      0.004     -6.454      0.000      -0.037      -0.020
# ==========================================================================================================================================================
# """

# %% [markdown]
# ## Modelo en media

# %%
df_media = df[(df["NIVEL"] == 4) & (df["CODIGO_METODOLOGIA"] == 1)]

# %%
# sin b|alancear 
model= smf.logit(formula= formula, data= df_media).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.100571
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              REPITENTE   No. Observations:                65026
# Model:                          Logit   Df Residuals:                    64990
# Method:                           MLE   Df Model:                           35
# Date:                Fri, 01 Jul 2022   Pseudo R-squ.:                 0.07438
# Time:                        03:44:35   Log-Likelihood:                -6539.7
# converged:                       True   LL-Null:                       -7065.3
# Covariance Type:            nonrobust   LLR p-value:                5.399e-198
# ==========================================================================================================================================================
#                                                                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                 -5.0427      0.865     -5.827      0.000      -6.739      -3.347
# C(GENERO)[T.1]                                                                             0.5212      0.055      9.424      0.000       0.413       0.630
# C(DIR_NUM_LOCALIDAD)[T.2]                                                                  0.5157      0.415      1.242      0.214      -0.298       1.329
# C(DIR_NUM_LOCALIDAD)[T.3]                                                                  0.1612      0.340      0.474      0.635      -0.505       0.827
# C(DIR_NUM_LOCALIDAD)[T.4]                                                                  0.4241      0.206      2.054      0.040       0.019       0.829
# C(DIR_NUM_LOCALIDAD)[T.5]                                                                  0.5944      0.202      2.950      0.003       0.199       0.989
# C(DIR_NUM_LOCALIDAD)[T.6]                                                                  0.3378      0.221      1.529      0.126      -0.095       0.771
# C(DIR_NUM_LOCALIDAD)[T.7]                                                                  0.5128      0.198      2.590      0.010       0.125       0.901
# C(DIR_NUM_LOCALIDAD)[T.8]                                                                 -0.1806      0.205     -0.880      0.379      -0.583       0.222
# C(DIR_NUM_LOCALIDAD)[T.9]                                                                  0.2977      0.251      1.189      0.235      -0.193       0.789
# C(DIR_NUM_LOCALIDAD)[T.10]                                                                 0.2782      0.210      1.325      0.185      -0.133       0.690
# C(DIR_NUM_LOCALIDAD)[T.11]                                                                 0.3343      0.204      1.640      0.101      -0.065       0.734
# C(DIR_NUM_LOCALIDAD)[T.12]                                                                 0.1115      0.297      0.375      0.708      -0.471       0.694
# C(DIR_NUM_LOCALIDAD)[T.13]                                                                 0.2367      0.433      0.546      0.585      -0.613       1.086
# C(DIR_NUM_LOCALIDAD)[T.14]                                                                 0.5164      0.297      1.737      0.082      -0.066       1.099
# C(DIR_NUM_LOCALIDAD)[T.15]                                                                 0.0366      0.316      0.116      0.908      -0.583       0.656
# C(DIR_NUM_LOCALIDAD)[T.16]                                                                -0.1955      0.276     -0.707      0.479      -0.737       0.346
# C(DIR_NUM_LOCALIDAD)[T.17]                                                                 0.8949      0.366      2.445      0.014       0.177       1.612
# C(DIR_NUM_LOCALIDAD)[T.18]                                                                 0.6110      0.205      2.985      0.003       0.210       1.012
# C(DIR_NUM_LOCALIDAD)[T.19]                                                                 0.5119      0.202      2.536      0.011       0.116       0.908
# C(DIR_NUM_LOCALIDAD)[T.20]                                                                 0.3517      0.772      0.456      0.649      -1.161       1.865
# C(todos_servicios_Pub)[T.1]                                                                0.0172      0.082      0.211      0.833      -0.143       0.177
# C(computador)[T.1]                                                                         0.0194      0.070      0.277      0.782      -0.118       0.157
# C(OVERAGE)[T.1]                                                                            1.4703      0.089     16.508      0.000       1.296       1.645
# C(ES_BILINGUE)[T.1]                                                                       -0.5940      0.203     -2.926      0.003      -0.992      -0.196
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_crítico]     0.0291      0.100      0.293      0.770      -0.166       0.224
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_medio]      -0.0123      0.061     -0.201      0.841      -0.132       0.107
# C(TIPO_DISCAPACIDAD)[T.1]                                                                 -0.1674      0.162     -1.031      0.302      -0.485       0.151
# C(tiene_auto)[T.1]                                                                        -0.1946      0.189     -1.031      0.302      -0.565       0.175
# estrato                                                                                    0.0216      0.050      0.430      0.667      -0.077       0.120
# EDAD                                                                                       0.0359      0.036      1.008      0.314      -0.034       0.106
# puntaje_sisben_3                                                                          -0.0015      0.002     -0.791      0.429      -0.005       0.002
# PROP_DOCENTES_CON_TITULO                                                                   0.5340      0.106      5.045      0.000       0.327       0.741
# promepuntaje                                                                              -0.0013      0.002     -0.563      0.573      -0.006       0.003
# COMPU_POR_ALUMN                                                                            0.2140      0.207      1.033      0.302      -0.192       0.620
# ALUMN_POR_DOCENTE                                                                         -0.0175      0.008     -2.243      0.025      -0.033      -0.002
# ==========================================================================================================================================================
# """

# %%
# balanceado 
df_media_rep = df_media[df_media['REPITENTE'] == 1]
df_media_no_rep = df_media[df_media['REPITENTE'] == 0].sample(n=df_media_rep.shape[0], random_state=145)
df_media_balanc = pd.concat([df_media_rep, df_media_no_rep])

# %%
model= smf.logit(formula= formula, data= df_media_balanc).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.612143
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              REPITENTE   No. Observations:                 2962
# Model:                          Logit   Df Residuals:                     2926
# Method:                           MLE   Df Model:                           35
# Date:                Fri, 01 Jul 2022   Pseudo R-squ.:                  0.1169
# Time:                        03:45:51   Log-Likelihood:                -1813.2
# converged:                       True   LL-Null:                       -2053.1
# Covariance Type:            nonrobust   LLR p-value:                 1.469e-79
# ==========================================================================================================================================================
#                                                                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                 -2.6872      1.334     -2.014      0.044      -5.302      -0.072
# C(GENERO)[T.1]                                                                             0.6024      0.081      7.446      0.000       0.444       0.761
# C(DIR_NUM_LOCALIDAD)[T.2]                                                                  1.2913      0.750      1.722      0.085      -0.178       2.761
# C(DIR_NUM_LOCALIDAD)[T.3]                                                                  0.6055      0.484      1.251      0.211      -0.343       1.554
# C(DIR_NUM_LOCALIDAD)[T.4]                                                                  0.6693      0.292      2.293      0.022       0.097       1.241
# C(DIR_NUM_LOCALIDAD)[T.5]                                                                  0.8472      0.284      2.987      0.003       0.291       1.403
# C(DIR_NUM_LOCALIDAD)[T.6]                                                                  0.6555      0.312      2.099      0.036       0.044       1.267
# C(DIR_NUM_LOCALIDAD)[T.7]                                                                  0.8130      0.277      2.931      0.003       0.269       1.357
# C(DIR_NUM_LOCALIDAD)[T.8]                                                                  0.0421      0.282      0.149      0.882      -0.512       0.596
# C(DIR_NUM_LOCALIDAD)[T.9]                                                                  0.7734      0.366      2.116      0.034       0.057       1.490
# C(DIR_NUM_LOCALIDAD)[T.10]                                                                 0.8525      0.301      2.831      0.005       0.262       1.443
# C(DIR_NUM_LOCALIDAD)[T.11]                                                                 0.5944      0.285      2.086      0.037       0.036       1.153
# C(DIR_NUM_LOCALIDAD)[T.12]                                                                -0.0829      0.418     -0.198      0.843      -0.902       0.736
# C(DIR_NUM_LOCALIDAD)[T.13]                                                                 0.4953      0.654      0.757      0.449      -0.787       1.777
# C(DIR_NUM_LOCALIDAD)[T.14]                                                                 0.7337      0.465      1.579      0.114      -0.177       1.644
# C(DIR_NUM_LOCALIDAD)[T.15]                                                                 1.1651      0.513      2.271      0.023       0.159       2.171
# C(DIR_NUM_LOCALIDAD)[T.16]                                                                 0.3079      0.395      0.780      0.435      -0.466       1.081
# C(DIR_NUM_LOCALIDAD)[T.17]                                                                 0.3936      0.550      0.716      0.474      -0.684       1.471
# C(DIR_NUM_LOCALIDAD)[T.18]                                                                 0.6471      0.287      2.255      0.024       0.085       1.210
# C(DIR_NUM_LOCALIDAD)[T.19]                                                                 0.6692      0.281      2.380      0.017       0.118       1.220
# C(DIR_NUM_LOCALIDAD)[T.20]                                                                 0.7950      1.336      0.595      0.552      -1.823       3.413
# C(todos_servicios_Pub)[T.1]                                                                0.0040      0.124      0.032      0.974      -0.239       0.247
# C(computador)[T.1]                                                                         0.0167      0.105      0.159      0.874      -0.190       0.223
# C(OVERAGE)[T.1]                                                                            1.1445      0.136      8.394      0.000       0.877       1.412
# C(ES_BILINGUE)[T.1]                                                                       -0.7292      0.274     -2.664      0.008      -1.266      -0.193
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_crítico]     0.0491      0.154      0.319      0.750      -0.253       0.351
# C(nivel_hacinamiento, Treatment(reference="Sin_hacinamiento"))[T.Hacinamiento_medio]       0.0447      0.093      0.479      0.632      -0.138       0.227
# C(TIPO_DISCAPACIDAD)[T.1]                                                                 -0.0766      0.277     -0.277      0.782      -0.619       0.466
# C(tiene_auto)[T.1]                                                                        -0.0416      0.274     -0.152      0.879      -0.579       0.496
# estrato                                                                                   -0.0248      0.076     -0.327      0.744      -0.173       0.124
# EDAD                                                                                       0.1876      0.061      3.076      0.002       0.068       0.307
# puntaje_sisben_3                                                                       -1.758e-05      0.003     -0.006      0.995      -0.006       0.006
# PROP_DOCENTES_CON_TITULO                                                                   0.5818      0.153      3.791      0.000       0.281       0.883
# promepuntaje                                                                              -0.0053      0.003     -1.594      0.111      -0.012       0.001
# COMPU_POR_ALUMN                                                                           -0.2839      0.352     -0.806      0.420      -0.975       0.407
# ALUMN_POR_DOCENTE                                                                         -0.0255      0.012     -2.061      0.039      -0.050      -0.001
# ==========================================================================================================================================================
# """

# %% [markdown]
# ## Variables de consideracion final

# %%
variables = ['estrato',
             'EDAD',
             'puntaje_sisben_3',
             'PROP_DOCENTES_CON_TITULO',
             'promepuntaje',
             'COMPU_POR_ALUMN', 
            ]


categorias= ['GENERO',  
             'DIR_NUM_LOCALIDAD',
             'todos_servicios_Pub',
             'computador',
             'OVERAGE',
             'ES_BILINGUE',
             "nivel_hacinamiento",
             "TIPO_DISCAPACIDAD",
             "tiene_auto"
             ]
